# %% [markdown]
# <a href="https://colab.research.google.com/github/Sri-Pooja00/2203A51341_NLP/blob/main/2203A51341_07_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Small dataset of English-French sentence pairs
data = [
    ("hello", "bonjour"),
    ("how are you", "comment ça va"),
    ("I am fine", "je vais bien"),
    ("what is your name", "comment tu t'appelles"),
    ("my name is", "je m'appelle"),
    ("thank you", "merci"),
    ("goodbye", "au revoir")
]

# Separate English and French sentences
english_sentences, french_sentences = zip(*data)

# Tokenization
eng_tokenizer = Tokenizer()
fr_tokenizer = Tokenizer()

eng_tokenizer.fit_on_texts(english_sentences)
fr_tokenizer.fit_on_texts(french_sentences)

# Convert to sequences
eng_sequences = eng_tokenizer.texts_to_sequences(english_sentences)
fr_sequences = fr_tokenizer.texts_to_sequences(french_sentences)

# Padding
max_eng_len = max(len(seq) for seq in eng_sequences)
max_fr_len = max(len(seq) for seq in fr_sequences)

eng_padded = pad_sequences(eng_sequences, maxlen=max_eng_len, padding='post')
fr_padded = pad_sequences(fr_sequences, maxlen=max_fr_len, padding='post')

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Embedding

# Define the LSTM encoder
latent_dim = 256  # Number of units in the LSTM layer
vocab_size = len(eng_tokenizer.word_index) + 1 # Get vocabulary size
embedding_dim = 128 # Define embedding dimension


encoder_inputs = Input(shape=(None,))
# Add Embedding layer to handle variable-length input and map words to vectors
encoder_embedding = Embedding(input_dim=vocab_size, output_dim=embedding_dim)(encoder_inputs)
encoder_outputs, state_h, state_c = LSTM(latent_dim, return_state=True)(encoder_embedding)

# Decoder
decoder_inputs = Input(shape=(None,))
# Add Embedding layer for the decoder
decoder_embedding = Embedding(input_dim=len(fr_tokenizer.word_index) + 1, output_dim=embedding_dim)(decoder_inputs)
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_embedding, initial_state=[state_h, state_c])
decoder_dense = Dense(len(fr_tokenizer.word_index) + 1, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# Model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
# Preparing the target data by shifting it for teacher forcing
target_data = np.zeros((len(french_sentences), max_fr_len, len(fr_tokenizer.word_index) + 1), dtype="float32")

for i, sequence in enumerate(fr_sequences):
    for t, word in enumerate(sequence):
        if t > 0:
            target_data[i, t - 1, word] = 1

# %%
model.compile(optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"])

# Train the model
history = model.fit([eng_padded, fr_padded], target_data, batch_size=64, epochs=100, validation_split=0.2)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.2000 - loss: 1.2323 - val_accuracy: 0.0000e+00 - val_loss: 0.4403
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.1333 - loss: 1.2238 - val_accuracy: 0.0000e+00 - val_loss: 0.4419
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.2667 - loss: 1.2165 - val_accuracy: 0.0000e+00 - val_loss: 0.4435
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.2667 - loss: 1.2094 - val_accuracy: 0.0000e+00 - val_loss: 0.4453
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.3333 - loss: 1.2021 - val_accuracy: 0.0000e+00 - val_loss: 0.4473
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.3333 - loss: 1.1941 - val_accuracy: 0.0000e+00 - val_loss: 0.4497
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.3333 - loss: 1.1854 - val_accuracy: 0.0000e+00 - val_loss: 0.4526
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.3333 - loss: 1.1756 - val_accuracy: 0.0000e+00 - val_loss: 0.4562
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.3333 - loss: 1.1645 - val_accuracy: 0.0000e+00 - val_loss: 0.4607
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.3333 - loss: 1.1518 - val_accuracy: 0.0000e+00 - val_loss: 0.4665
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.3333 - loss: 1.1371 - val_accuracy: 0.0000e+00 - val_loss: 0.4743
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.3333 - loss: 1.1199 - val_accuracy: 0.0000e+00 - val_loss: 0.4847
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.3333 - loss: 1.0996 - val_accuracy: 0.0000e+00 - val_loss: 0.4993
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.3333 - loss: 1.0756 - val_accuracy: 0.0000e+00 - val_loss: 0.5198
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.2667 - loss: 1.0470 - val_accuracy: 0.0000e+00 - val_loss: 0.5481
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.2667 - loss: 1.0139 - val_accuracy: 0.0000e+00 - val_loss: 0.5849
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.2667 - loss: 0.9792 - val_accuracy: 0.0000e+00 - val_loss: 0.6273
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.2667 - loss: 0.9486 - val_accuracy: 0.0000e+00 - val_loss: 0.6709
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.2667 - loss: 0.9263 - val_accuracy: 0.0000e+00 - val_loss: 0.7126
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.2667 - loss: 0.9111 - val_accuracy: 0.0000e+00 - val_loss: 0.7494
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.2000 - loss: 0.9002 - val_accuracy: 0.0000e+00 - val_loss: 0.7782
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.2000 - loss: 0.8926 - val_accuracy: 0.0000e+00 - val_loss: 0.7978
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.2000 - loss: 0.8874 - val_accuracy: 0.0000e+00 - val_loss: 0.8103
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.2000 - loss: 0.8836 - val_accuracy: 0.0000e+00 - val_loss: 0.8186
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.2000 - loss: 0.8802 - val_accuracy: 0.0000e+00 - val_loss: 0.8246
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.2000 - loss: 0.8768 - val_accuracy: 0.0000e+00 - val_loss: 0.8293
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.2000 - loss: 0.8735 - val_accuracy: 0.0000e+00 - val_loss: 0.8333
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.2667 - loss: 0.8702 - val_accuracy: 0.0000e+00 - val_loss: 0.8367
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.2667 - loss: 0.8670 - val_accuracy: 0.0000e+00 - val_loss: 0.8396
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.2667 - loss: 0.8641 - val_accuracy: 0.0000e+00 - val_loss: 0.8420
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.2667 - loss: 0.8613 - val_accuracy: 0.0000e+00 - val_loss: 0.8438
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.2667 - loss: 0.8587 - val_accuracy: 0.0000e+00 - val_loss: 0.8452
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.2667 - loss: 0.8559 - val_accuracy: 0.0000e+00 - val_loss: 0.8462
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.2667 - loss: 0.8536 - val_accuracy: 0.0000e+00 - val_loss: 0.8470
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.2000 - loss: 0.8492 - val_accuracy: 0.0000e+00 - val_loss: 0.8473
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.2000 - loss: 0.8501 - val_accuracy: 0.0000e+00 - val_loss: 0.8480
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.3333 - loss: 0.8467 - val_accuracy: 0.0000e+00 - val_loss: 0.8480
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.2667 - loss: 0.8423 - val_accuracy: 0.0000e+00 - val_loss: 0.8480
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.2667 - loss: 0.8380 - val_accuracy: 0.0000e+00 - val_loss: 0.8482
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.2667 - loss: 0.8343 - val_accuracy: 0.0000e+00 - val_loss: 0.8482
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.2667 - loss: 0.8295 - val_accuracy: 0.0000e+00 - val_loss: 0.8488
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.3333 - loss: 0.8253 - val_accuracy: 0.0000e+00 - val_loss: 0.8487
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.3333 - loss: 0.8178 - val_accuracy: 0.0000e+00 - val_loss: 0.8490
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.4000 - loss: 0.8128 - val_accuracy: 0.0000e+00 - val_loss: 0.8488
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.4667 - loss: 0.8107 - val_accuracy: 0.0000e+00 - val_loss: 0.8457
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.4667 - loss: 0.8001 - val_accuracy: 0.0000e+00 - val_loss: 0.8476
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.4667 - loss: 0.7914 - val_accuracy: 0.0000e+00 - val_loss: 0.8451
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.4000 - loss: 0.7885 - val_accuracy: 0.0000e+00 - val_loss: 0.8461
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.4667 - loss: 0.7761 - val_accuracy: 0.0000e+00 - val_loss: 0.8460
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.4667 - loss: 0.7707 - val_accuracy: 0.0000e+00 - val_loss: 0.8474
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.4667 - loss: 0.7544 - val_accuracy: 0.0000e+00 - val_loss: 0.8431
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.4000 - loss: 0.7501 - val_accuracy: 0.0000e+00 - val_loss: 0.8438
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.4667 - loss: 0.7343 - val_accuracy: 0.0000e+00 - val_loss: 0.8464
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.4667 - loss: 0.7276 - val_accuracy: 0.0000e+00 - val_loss: 0.8454
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.4667 - loss: 0.7112 - val_accuracy: 0.0000e+00 - val_loss: 0.8432
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.4667 - loss: 0.7060 - val_accuracy: 0.0000e+00 - val_loss: 0.8438
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.4667 - loss: 0.6867 - val_accuracy: 0.0000e+00 - val_loss: 0.8450
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.4667 - loss: 0.6836 - val_accuracy: 0.0000e+00 - val_loss: 0.8442
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.4667 - loss: 0.6613 - val_accuracy: 0.0000e+00 - val_loss: 0.8440
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.4667 - loss: 0.6595 - val_accuracy: 0.0000e+00 - val_loss: 0.8429
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.4667 - loss: 0.6362 - val_accuracy: 0.0000e+00 - val_loss: 0.8455
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.4667 - loss: 0.6352 - val_accuracy: 0.0000e+00 - val_loss: 0.8438
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4667 - loss: 0.6090 - val_accuracy: 0.0000e+00 - val_loss: 0.8448
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.4667 - loss: 0.6086 - val_accuracy: 0.0000e+00 - val_loss: 0.8441
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.4667 - loss: 0.5771 - val_accuracy: 0.0000e+00 - val_loss: 0.8471
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.4667 - loss: 0.5812 - val_accuracy: 0.0000e+00 - val_loss: 0.8435
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.4667 - loss: 0.5438 - val_accuracy: 0.0000e+00 - val_loss: 0.8445
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.4667 - loss: 0.5564 - val_accuracy: 0.0000e+00 - val_loss: 0.8429
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.4667 - loss: 0.5096 - val_accuracy: 0.0000e+00 - val_loss: 0.8417
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.4667 - loss: 0.5320 - val_accuracy: 0.0000e+00 - val_loss: 0.8400
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.4667 - loss: 0.4795 - val_accuracy: 0.0000e+00 - val_loss: 0.8437
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.4667 - loss: 0.5009 - val_accuracy: 0.0000e+00 - val_loss: 0.8404
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.4667 - loss: 0.4455 - val_accuracy: 0.0000e+00 - val_loss: 0.8426
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.4667 - loss: 0.4812 - val_accuracy: 0.0000e+00 - val_loss: 0.8394
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.4667 - loss: 0.4181 - val_accuracy: 0.0000e+00 - val_loss: 0.8425
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.4667 - loss: 0.4586 - val_accuracy: 0.0000e+00 - val_loss: 0.8400
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.4667 - loss: 0.3935 - val_accuracy: 0.0000e+00 - val_loss: 0.8415
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.4667 - loss: 0.4393 - val_accuracy: 0.0000e+00 - val_loss: 0.8395
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.4667 - loss: 0.3758 - val_accuracy: 0.0000e+00 - val_loss: 0.8411
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.4667 - loss: 0.4176 - val_accuracy: 0.0000e+00 - val_loss: 0.8391
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.4667 - loss: 0.3563 - val_accuracy: 0.0000e+00 - val_loss: 0.8408
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.4667 - loss: 0.4024 - val_accuracy: 0.0000e+00 - val_loss: 0.8390
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.4667 - loss: 0.3372 - val_accuracy: 0.0000e+00 - val_loss: 0.8397
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.4667 - loss: 0.3891 - val_accuracy: 0.0000e+00 - val_loss: 0.8380
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.4667 - loss: 0.3213 - val_accuracy: 0.0000e+00 - val_loss: 0.8391
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.4667 - loss: 0.3805 - val_accuracy: 0.0000e+00 - val_loss: 0.8377
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.4667 - loss: 0.3101 - val_accuracy: 0.0000e+00 - val_loss: 0.8382
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.4667 - loss: 0.3624 - val_accuracy: 0.0000e+00 - val_loss: 0.8372
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.4667 - loss: 0.2960 - val_accuracy: 0.0000e+00 - val_loss: 0.8375
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.4667 - loss: 0.3569 - val_accuracy: 0.0000e+00 - val_loss: 0.8365
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.4667 - loss: 0.2873 - val_accuracy: 0.0000e+00 - val_loss: 0.8368
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.4667 - loss: 0.3422 - val_accuracy: 0.0000e+00 - val_loss: 0.8360
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.4667 - loss: 0.2774 - val_accuracy: 0.0000e+00 - val_loss: 0.8364
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.4667 - loss: 0.3364 - val_accuracy: 0.0000e+00 - val_loss: 0.8355
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.4667 - loss: 0.2668 - val_accuracy: 0.0000e+00 - val_loss: 0.8357
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.4667 - loss: 0.3335 - val_accuracy: 0.0000e+00 - val_loss: 0.8351
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.4667 - loss: 0.2618 - val_accuracy: 0.0000e+00 - val_loss: 0.8350
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.4667 - loss: 0.3256 - val_accuracy: 0.0000e+00 - val_loss: 0.8343
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.4667 - loss: 0.2550 - val_accuracy: 0.0000e+00 - val_loss: 0.8344
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.4667 - loss: 0.3186 - val_accuracy: 0.0000e+00 - val_loss: 0.8339

# %%
# Define inference models
encoder_model = Model(encoder_inputs, [state_h, state_c])

# Decoder setup
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_outputs, state_h, state_c = decoder_lstm(decoder_embedding, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model([decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states)

# %%
def translate_sentence(input_seq):
    # Encode the input sequence to get the states
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1
    target_seq = np.zeros((1, 1))

    # Populate the first token of target sequence with the start token
    target_seq[0, 0] = fr_tokenizer.word_index['<start>']

    translated_sentence = []
    while True:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_word = fr_tokenizer.index_word[sampled_token_index]
        translated_sentence.append(sampled_word)

        # Exit condition: either hit max length or find stop token.
        if sampled_word == '<end>' or len(translated_sentence) > max_fr_len:
            break

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1))
        target_seq[0, 0] = sampled_token_index

        # Update states
        states_value = [h, c]

    return ' '.join(translated_sentence)

# %%
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Function to preprocess the input sentence
def preprocess_sentence(sentence, tokenizer, max_len):
    sentence_seq = tokenizer.texts_to_sequences([sentence])
    padded_sentence = pad_sequences(sentence_seq, maxlen=max_len, padding='post')
    return padded_sentence

# Function to translate an English sentence to French
def translate_sentence(sentence):
    # Preprocess input sentence
    input_seq = preprocess_sentence(sentence, eng_tokenizer, max_eng_len)

    # Encode the input sentence to get initial states
    states_value = encoder_model.predict(input_seq)

    # Initialize the target sequence with the start token
    start_token_index = fr_tokenizer.word_index.get('<start>', 1)  # 1 if '<start>' not found
    target_seq = np.zeros((1, 1))
    target_seq[0, 0] = start_token_index

    # Store the translation result
    translated_sentence = []

    # Generate translation word by word
    while True:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Get the index of the most likely word
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_word = fr_tokenizer.index_word.get(sampled_token_index, '')

        # Exit if end token is found or max length is reached
        if sampled_word == '<end>' or len(translated_sentence) > max_fr_len:
            break

        translated_sentence.append(sampled_word)

        # Update the target sequence and states for the next iteration
        target_seq = np.zeros((1, 1))
        target_seq[0, 0] = sampled_token_index
        states_value = [h, c]

    # Join the list of words into a single string
    return ' '.join(translated_sentence)

# Taking input from the user
english_sentence = input("Enter an English sentence to translate: ")
french_translation = translate_sentence(english_sentence)

print("English:", english_sentence)
print("French:", french_translation)
# Out:
# Enter an English sentence to translate: What are you doing?
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# English: What are you doing?
# French: ça va va bien
